# %% [markdown]
# # Se crean los esquemas para las diferentes etapas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.ferreteria_bronze;
CREATE SCHEMA IF NOT EXISTS workspace.ferreteria_silver;
CREATE SCHEMA IF NOT EXISTS workspace.ferreteria_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Luego de la creacion, se suben los diferentes csv a la capa bronze.
